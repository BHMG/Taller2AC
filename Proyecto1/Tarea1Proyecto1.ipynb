# %%
#data
import pandas as pd
import statistics as st
from ucimlrepo import fetch_ucirepo 
import matplotlib.pyplot as plt
import seaborn as sns
  
# fetch dataset 
predict_students_dropout_and_academic_success = fetch_ucirepo(id=697) 
  
# data (as pandas dataframes) 
X = predict_students_dropout_and_academic_success.data.features 
y = predict_students_dropout_and_academic_success.data.targets

# %%
# metadata 
#dfmeta= pd.DataFrame(predict_students_dropout_and_academic_success.metadata) 
# variable information 
#dfvarinfo=pd.DataFrame(predict_students_dropout_and_academic_success.variables)

#predict_students_dropout_and_academic_success.to_csv('prueba.csv', encoding='utf-8', index=False)

dfx=pd.DataFrame(X)
dfy=pd.DataFrame(y)


dfx.to_csv('pruebax.csv', encoding='utf-8', index=False)
dfy.to_csv('prueba.csv', encoding='utf-8', index=False)

#dfmeta.to_csv('meta.csv', encoding='utf-8', index=False)
#dfvarinfo.to_csv('info.csv', encoding='utf-8', index=False)

# %%
data = pd.concat([dfx, dfy], axis=1)
data_og =data
print(data)
print(data.describe)
# Out:
#       Marital Status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
#print(X.describe())

#print(data)
#data.plot( data, kind=)
#plt.show()

df=data.groupby(['Course','Target']).size()
df=df.unstack()
df.plot(kind='bar')
# Out:
# <Axes: xlabel='Course'>

# %%
#volver los datos niveles de un anova
#df['Color'] = df['Color'].astype('category')
data['Course'] = data['Course'].astype('category')

# %%
for i in data:
    aux=data[i]
    data[i]=data[i].astype('category')
    print('listo'+ i)
# Out:
# listoMarital Status
# listoApplication mode
# listoApplication order
# listoCourse
# listoDaytime/evening attendance
# listoPrevious qualification
# listoPrevious qualification (grade)
# listoNacionality
# listoMother's qualification
# listoFather's qualification
# listoMother's occupation
# listoFather's occupation
# listoAdmission grade
# listoDisplaced
# listoEducational special needs
# listoDebtor
# listoTuition fees up to date
# listoGender
# listoScholarship holder
# listoAge at enrollment
# listoInternational
# listoCurricular units 1st sem (credited)
# listoCurricular units 1st sem (enrolled)
# listoCurricular units 1st sem (evaluations)
# listoCurricular units 1st sem (approved)
# listoCurricular units 1st sem (grade)
# listoCurricular units 1st sem (without evaluations)
# listoCurricular units 2nd sem (credited)
# listoCurricular units 2nd sem (enrolled)
# listoCurricular units 2nd sem (evaluations)
# listoCurricular units 2nd sem (approved)
# ...

# %%
#print(data)
data.describe()
# Out:
#         Marital Status  Application mode  Application order  Course  \
# count             4424              4424               4424    4424
# unique               6                18                  8      17
# top                  1                 1                  1    9500
# freq              3919              1708               3026     766
#
#         Daytime/evening attendance  Previous qualification  \
# count                         4424                    4424
# unique                           2                      17
# top                              1                       1
# freq                          3941                    3717
#
#         Previous qualification (grade)  Nacionality  Mother's qualification  \
# count                           4424.0         4424                    4424
# unique                           101.0           21                      29
# top                              133.1            1                       1
# ...

# %%
def crearGrafoBar(str):
    df=data.groupby([str,'Target']).size()
    df=df.unstack()
    df.plot(kind='bar')

crearGrafoBar('Marital Status')

# %%
#caja de gatos
#plt.boxplot(data['Target'])

def crearGrafoCat(par):
    df=data.groupby([par,'Target']).size()
    df=df.unstack()
    #df.plot(kind='bar')
    #plt.boxplot(df)
    sns.boxplot(x='Target', data=df, palette="Set3")


#crearGrafoCat('Course')
df=data.groupby(['Course','Target']).size()
df=df.unstack()
#print(df)
sns.boxplot(x='Target', y= 'Marital Status', data=data_og, palette="Set3")
# Out:
# <Axes: xlabel='Target', ylabel='Marital Status'>
